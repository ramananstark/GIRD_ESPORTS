# %%
#import pandas as pd
#import json

#path="C:\\Users\\raman\\Downloads\\csgo\\csgo\\CCT-Online-Finals-1\\2579048_events.jsonl"

#df=pd.read_json(path,lines=True)

#df.shape


#df.info()
#(df.head())
#df.columns

#events=pd.DataFrame()
#for index,row in df.iterrows():
#    events=pd.concat([events,pd.json_normalize(row['events'])])
#    events.reset_index(drop=True,inplace=True)
    
#events

# %%
import json
import pandas as pd
json_dicts1=[]
data1="C:\\Users\\raman\\Downloads\\csgo\\csgo\\CCT-Online-Finals-1\\2579048_events.jsonl"
with open(data1) as f:
    lines=f.read().splitlines()
    
    for line in lines:
        json_dicts1.append(json.loads(line))
    
    
df1=pd.DataFrame(json_dicts1)    
df1
#df1.columns
#df1.shape
# Out:
#                                         id                occurredAt  \
# 0     c1c9410b-578e-4476-9d89-447c5a73cb96  2023-05-30T14:32:40.584Z
# 1     bd9e15fb-4afa-4562-9481-b5d966cea867  2023-05-30T14:32:40.584Z
# 2     3aedc7ea-2a76-4d24-b27f-fa4c99221934  2023-05-30T14:32:40.584Z
# 3     fd246ad5-9c8f-4ac7-ba0d-c3c7ab8234cf  2023-05-30T14:32:40.584Z
# 4     0c834ddc-0ef1-4fbb-b5b1-6efde49612b8  2023-05-30T14:32:40.584Z
# ...                                    ...                       ...
# 6649  23ae9cb6-533b-49a8-bafb-22465aaa1a28  2023-05-30T16:52:34.173Z
# 6650  e3ecc858-859d-494a-9826-209d1e3088b1  2023-05-30T16:52:34.173Z
# 6651  b2e46e11-9214-45c8-9ff9-79af4c229241  2023-05-30T16:52:34.173Z
# 6652  6721f869-099b-43d5-8d2e-189f4b025770  2023-05-30T16:52:34.173Z
# 6653  09062fee-0bca-45a8-8341-0be0537d6f8d  2023-05-30T16:52:34.173Z
#
#                              correlationId               publishedAt seriesId  \
# 0     96e5b343-9918-4158-b83f-5967d4d73772  1970-01-01T00:00:00.000Z  2579048
# 1     96e5b343-9918-4158-b83f-5967d4d73772  1970-01-01T00:00:00.000Z  2579048
# 2     96e5b343-9918-4158-b83f-5967d4d73772  1970-01-01T00:00:00.000Z  2579048
# 3     96e5b343-9918-4158-b83f-5967d4d73772  1970-01-01T00:00:00.000Z  2579048
# 4     96e5b343-9918-4158-b83f-5967d4d73772  1970-01-01T00:00:00.000Z  2579048
# ...                                    ...                       ...      ...
# 6649  6f2a20a7-fd80-401f-ba89-6fbdfcfc6a9e  1970-01-01T00:00:00.000Z  2579048
# 6650  6f2a20a7-fd80-401f-ba89-6fbdfcfc6a9e  1970-01-01T00:00:00.000Z  2579048
# 6651  6f2a20a7-fd80-401f-ba89-6fbdfcfc6a9e  1970-01-01T00:00:00.000Z  2579048
# 6652  6f2a20a7-fd80-401f-ba89-6fbdfcfc6a9e  1970-01-01T00:00:00.000Z  2579048
# 6653  6f2a20a7-fd80-401f-ba89-6fbdfcfc6a9e  1970-01-01T00:00:00.000Z  2579048
#
#       sequenceNumber  sessionSequenceNumber  \
# 0                  1                      1
# 1                  2                      2
# 2                  3                      3
# 3                  4                      4
# 4                  5                      5
# ...              ...                    ...
# 6649            6650                   6650
# 6650            6651                   6651
# 6651            6652                   6652
# 6652            6653                   6653
# 6653            6654                   6654
#
#                                                  events
# 0     [{'id': 'c3cfb29a-6699-4a86-b251-7dd99893d25c'...
# 1     [{'id': 'c04cc72f-075f-408f-8d96-00a0339da28a'...
# 2     [{'id': '3ae96b5b-b08c-4351-a877-d87a58e8f2f4'...
# 3     [{'id': 'e5a2e7ce-8be7-4679-baeb-bacc142736a5'...
# 4     [{'id': '055d1362-061a-4269-985f-f3447229715b'...
# ...                                                 ...
# 6649  [{'id': '81637b59-047c-49cd-8cb0-d4173361f81b'...
# 6650  [{'id': '26dd1062-47d4-48c3-859e-a6a1be79d2fb'...
# 6651  [{'id': 'af4bcfc7-5948-467c-891a-e38ee6906623'...
# 6652  [{'id': 'ac8a665b-f10a-4244-86a9-7f3648e2c92d'...
# 6653  [{'id': '6731c9e7-fe8a-4f1c-bbd6-76b068bb8894'...
#
# [6654 rows x 8 columns]

# %%
events = pd.DataFrame()
for index, row in df1.iterrows():
    events = pd.concat([events,pd.json_normalize(row['events'])])
events.reset_index(drop=True,inplace=True) 
#events

x=events.loc[events['type']=='game-ended-round']


#x.to_excel('game-ended-round.xlsx',index=False)
x

#y=x.loc[x['target']=='']
# Out:
#                                         id  includesFullState  \
# 109   a487293e-25b3-4630-af62-8b0c7644bf2a               True
# 187   cec2337f-d7b9-4285-b0f4-b24375120e46               True
# 282   ed9b12c7-d9ca-4d0a-8209-dc9989592ad4               True
# 386   cad97cc3-7ded-4181-a5f2-258831ef5cef               True
# 519   4460c3f7-9617-4170-9483-061b646598c9               True
# 660   537a709a-4ce3-44ed-a97c-0b6aa811f571               True
# 774   52c124a5-e6b2-4e28-83a0-244474344847               True
# 923   c85257bd-2293-4691-9b27-b6e605a5a9a7               True
# 1064  8c2695df-0005-4cfb-8fbe-7c58fba1202c               True
# 1220  7c62a63f-240c-4669-b270-03377a633d5d               True
# 1345  2d0808c9-a445-4a09-8326-57855b99c49c               True
# 1400  388a35ac-eadb-4f4b-ba40-c5735fab0091               True
# 1521  641df011-1898-4081-95c6-f1c2bd2a7074               True
# 1647  3a75e980-60aa-4c48-ab23-b33e89d1da7a               True
# 1787  a5f88c30-af8e-4099-8027-ec1c94e23fd3               True
# 1851  55a983a5-a8c3-4385-93d6-5328b2b178a4               True
# 1996  590224ed-0115-49db-ae11-2f5152e70575               True
# 2090  390143d2-d8d0-4b30-bb89-5eaa86093007               True
# 2185  0a3ba84e-9d55-4eea-bd12-b857ea53ef4b               True
# 2277  5b6f976d-e9e6-451b-b663-e80bad407277               True
# 2374  5177ceb8-1186-4bcb-bb14-d751e012c146               True
# 2486  a2aa0d2b-5477-4fb5-8c35-b56f55dd7f6c               True
# 2621  3ea2cf69-d85d-4b18-8286-4d0a99e7d488               True
# 2758  83fff895-fda4-42a5-9130-5b4b071ab825               True
# 2896  a6ba399f-484c-456f-bcc5-54ea62057d46               True
# 3012  816a1867-c3b5-4e27-9880-823d151a642f               True
# 3117  316e9a26-cbf3-4bd9-a6ce-e855e81909d5               True
# 3261  80491196-97e6-4889-9128-6c4e0dfb7cf3               True
# 3390  c4d8c95b-bbca-498c-aa9d-7e0c94b00721               True
# 3528  cfc2b19a-b01c-4136-a044-e68ea74a6b11               True
# 3649  e2fab6d0-695a-475f-9d9b-77846a4cb997               True
# 3767  f4c469c1-4154-4c16-b9d4-97b3f7bb9b27               True
# 3889  b7b5e011-ac03-47a5-b053-982b0f73cb4b               True
# 4026  b117031b-15aa-488a-b40a-85d8ae2e4019               True
# 4107  c1f6d833-c349-4040-85ab-bb3735e076b2               True
# 4182  6b118f1b-b7b7-4348-abf5-63547910df22               True
# 4268  fe3eb69b-fa43-418e-96dd-ecb248ef7852               True
# 4389  564857ab-4058-45d6-9ae9-8a3540c2f2cc               True
# 4499  be45bbb4-f26f-464f-8d8f-8a1cc15a94d7               True
# 4649  c50717eb-0ad6-48d1-84b7-637308716bdf               True
# 4767  e90e452b-94f9-4e50-ade4-e1267fc1feea               True
# 4896  21770630-cbef-4d2b-bb29-6fb337a809f3               True
# 5004  dbd155fd-1cfd-4f08-af30-ae049f6d67e9               True
# 5125  5c994041-2585-4bd5-80b6-5c77df98e987               True
# 5259  49582414-bb0f-43ee-979f-20d5e43b30f0               True
# 5374  3b131f99-9b6e-4059-b34f-4b30cea68920               True
# 5518  1d740643-fcdd-42e0-b793-b5de76db94b6               True
# 5622  a9ea0372-5cc2-4ed9-a05c-0f35aa9799ba               True
# 5766  7c53f50d-6c1f-4ecb-bd38-f4848888b0e5               True
# 5842  1a06fc2a-2e1d-4b3b-8e07-7953487df4c8               True
# 5962  3cc79942-d903-4ed1-aa57-8e73cffc7f64               True
# 6066  f9ea363e-c5e3-4bfb-8bf7-bded4c173a97               True
# 6181  af90bc22-6862-4526-a746-3c75d0d425cb               True
# 6315  3c49d98d-3196-452d-906f-f8736b0d7b57               True
# 6454  c1b91f73-196f-4faf-837c-6b528f200956               True
# 6558  b25bf253-5503-43d9-a70c-8be38b74a4dc               True
# 6676  4c1e3284-5939-4085-8ca6-eaa54a769c5b               True
# 6801  becb534d-c909-464c-a3ec-6207ad1ddff6               True
# 6909  ac8a665b-f10a-4244-86a9-7f3648e2c92d               True
#
#                   type action actor.type  \
# 109   game-ended-round  ended       game
# 187   game-ended-round  ended       game
# 282   game-ended-round  ended       game
# 386   game-ended-round  ended       game
# 519   game-ended-round  ended       game
# 660   game-ended-round  ended       game
# 774   game-ended-round  ended       game
# 923   game-ended-round  ended       game
# 1064  game-ended-round  ended       game
# 1220  game-ended-round  ended       game
# 1345  game-ended-round  ended       game
# 1400  game-ended-round  ended       game
# 1521  game-ended-round  ended       game
# 1647  game-ended-round  ended       game
# 1787  game-ended-round  ended       game
# 1851  game-ended-round  ended       game
# 1996  game-ended-round  ended       game
# 2090  game-ended-round  ended       game
48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-12  ...
# 1521  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-13  ...
# 1647  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-14  ...
# 1787  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-15  ...
# 1851  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-16  ...
# 1996  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-17  ...
# 2090  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-18  ...
# 2185  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-19  ...
# 2277  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-20  ...
# 2374  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-21  ...
# 2486  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-22  ...
# 2621  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-23  ...
# 2758  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-24  ...
# 2896  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-25  ...
# 3012  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-26  ...
# 3117  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-27  ...
# 3261  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-28  ...
# 3390  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-29  ...
# 3528  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-30  ...
# 3649  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-31  ...
# 3767  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-32  ...
# 3889  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-33  ...
# 4026  48edea41-cfbf-4df4-9db1-95ceb5121f56       round  round-34  ...
# 4107  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-1  ...
# 4182  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-2  ...
# 4268  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-3  ...
# 4389  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-4  ...
# 4499  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-5  ...
# 4649  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-6  ...
# 4767  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-7  ...
# 4896  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-8  ...
# 5004  5158f4a5-02ac-47ee-b153-7796b5800d3f       round   round-9  ...
# 5125  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-10  ...
# 5259  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-11  ...
# 5374  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-12  ...
# 5518  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-13  ...
# 5622  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-14  ...
# 5766  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-15  ...
# 5842  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-16  ...
# 5962  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-17  ...
# 6066  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-18  ...
# 6181  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-19  ...
# 6315  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-20  ...
# 6454  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-21  ...
# 6558  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-22  ...
# 6676  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-23  ...
# 6801  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-24  ...
# 6909  5158f4a5-02ac-47ee-b153-7796b5800d3f       round  round-25  ...
#
#      actor.state.series.weaponKills.tec9 actor.state.game.weaponKills.tec9  \
# 109                                  NaN                               NaN
# 187                                  NaN                               NaN
# 282                                  NaN                               NaN
# 386                                  NaN                               NaN
# 519                                  NaN                               NaN
# 660                                  NaN                               NaN
# 774                                  NaN                               NaN
# 923                                  NaN                               NaN
# 1064                                 NaN                               NaN
# 1220                                 NaN                               NaN
# 1345                                 NaN                               NaN
# 1400                                 NaN                               NaN
# 1521                                 NaN                               NaN
# 1647                                 NaN                               NaN
# 1787                                 NaN                               NaN
# 1851                                 NaN                               NaN
# 1996                                 NaN                               NaN
# 2090                                 NaN                               NaN
# 2185                                 NaN                               NaN
# 2277                                 NaN                               NaN
# 2374                                 NaN                               NaN
# 2486                                 NaN                               NaN
# 2621                                 NaN                               NaN
# 2758                                 NaN                               NaN
# 2896                                 NaN                               NaN
# 3012                                 NaN                               NaN
# 3117                                 NaN                               NaN
# 3261                                 NaN                               NaN
# 3390                                 NaN                               NaN
# 3528                                 NaN                               NaN
# 3649                                 NaN                               NaN
# 3767                                 NaN                               NaN
# 3889                                 NaN                               NaN
# 4026                                 NaN                               NaN
# 4107                                 NaN                               NaN
# 4182                                 NaN                               NaN
# 4268                                 NaN                               NaN
# 4389                                 NaN                               NaN
# 4499                                 NaN                               NaN
# 4649                                 NaN                               NaN
# 4767                                 NaN                               NaN
# 4896                                 NaN                               NaN
# 5004                                 NaN                               NaN
# 5125                                 NaN                               NaN
# 5259                                 NaN                               NaN
# 5374                                 NaN                               NaN
# 5518                                 NaN                               NaN
# 5622                                 NaN                               NaN
# 5766                                 NaN                               NaN
# 5842                                 NaN                               NaN
# 5962                                 NaN                               NaN
# 6676                                     NaN                      NaN
# 6801                                     NaN                      NaN
# 6909                                     NaN                      NaN
#
#      actor.stateDelta.series.won seriesStateDelta.finished
# 109                          NaN                       NaN
# 187                          NaN                       NaN
# 282                          NaN                       NaN
# 386                          NaN                       NaN
# 519                          NaN                       NaN
# 660                          NaN                       NaN
# 774                          NaN                       NaN
# 923                          NaN                       NaN
# 1064                         NaN                       NaN
# 1220                         NaN                       NaN
# 1345                         NaN                       NaN
# 1400                         NaN                       NaN
# 1521                         NaN                       NaN
# 1647                         NaN                       NaN
# 1787                         NaN                       NaN
# 1851                         NaN                       NaN
# 1996                         NaN                       NaN
# 2090                         NaN                       NaN
# 2185                         NaN                       NaN
# 2277                         NaN                       NaN
# 2374                         NaN                       NaN
# 2486                         NaN                       NaN
# 2621                         NaN                       NaN
# 2758                         NaN                       NaN
# 2896                         NaN                       NaN
# 3012                         NaN                       NaN
# 3117                         NaN                       NaN
# 3261                         NaN                       NaN
# 3390                         NaN                       NaN
# 3528                         NaN                       NaN
# 3649                         NaN                       NaN
# 3767                         NaN                       NaN
# 3889                         NaN                       NaN
# 4026                         NaN                       NaN
# 4107                         NaN                       NaN
# 4182                         NaN                       NaN
# 4268                         NaN                       NaN
# 4389                         NaN                       NaN
# 4499                         NaN                       NaN
# 4649                         NaN                       NaN
# 4767                         NaN                       NaN
# 4896                         NaN                       NaN
# 5004                         NaN                       NaN
# 5125                         NaN                       NaN
# 5259                         NaN                       NaN
# 5374                         NaN                       NaN
# 5518                         NaN                       NaN
# 5622                         NaN                       NaN
# 5766                         NaN                       NaN
# 5842                         NaN                       NaN
# 5962                         NaN                       NaN
# 6066                         NaN                       NaN
# 6181                         NaN                       NaN
# 6315                         NaN                       NaN
# 6454                         NaN                       NaN
# 6558                         NaN                       NaN
# 6676                         NaN                       NaN
# 6801                         NaN                       NaN
# 6909                         NaN                       NaN
#
# [59 rows x 567 columns]

# %%
target_state_teams = pd.DataFrame()
for index, row in x.iterrows():
    target_state_teams = pd.concat([target_state_teams,pd.json_normalize(row['target.state.teams'])])
target_state_teams.reset_index(drop=True,inplace=True) 
y=target_state_teams
#y.to_excel('target_state_teams.xlsx',index=False)
y
# Out:
#         id          statePath   name                side    won  kills  \
# 0    47336  [{'id': '47336'}]  forZe          terrorists   True      5
# 1      927    [{'id': '927'}]   9INE  counter-terrorists  False      3
# 2    47336  [{'id': '47336'}]  forZe          terrorists   True      5
# 3      927    [{'id': '927'}]   9INE  counter-terrorists  False      0
# 4    47336  [{'id': '47336'}]  forZe          terrorists   True      5
# ..     ...                ...    ...                 ...    ...    ...
# 113    927    [{'id': '927'}]   9INE  counter-terrorists  False      3
# 114  47336  [{'id': '47336'}]  forZe          terrorists   True      5
# 115    927    [{'id': '927'}]   9INE  counter-terrorists  False      3
# 116  47336  [{'id': '47336'}]  forZe          terrorists   True      5
# 117    927    [{'id': '927'}]   9INE  counter-terrorists  False      2
#
#      killAssistsReceived  killAssistsGiven  \
# 0                      1                 1
# 1                      0                 0
# 2                      1                 1
# 3                      0                 0
# 4                      1                 1
# ..                   ...               ...
# 113                    0                 0
# 114                    1                 1
# 115                    1                 1
# 116                    1                 1
# 117                    1                 1
#
#                          killAssistsReceivedFromPlayer  teamkills  ...  \
# 0    [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# 1                                                   []          0  ...
# 2    [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# 3                                                   []          0  ...
# 4    [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# ..                                                 ...        ...  ...
# 113                                                 []          0  ...
# 114  [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# 115  [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# 116  [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
# 117  [{'id': 'killAssistsReceivedFromPlayer-7656119...          0  ...
#
#      weaponKills.aug  weaponKills.awp weaponKills.molotov  \
# 0                NaN              NaN                 NaN
# 1                NaN              NaN                 NaN
# 2                NaN              NaN                 NaN
# 3                NaN              NaN                 NaN
# 4                NaN              NaN                 NaN
# ..               ...              ...                 ...
# 113              NaN              NaN                 NaN
# 114              NaN              1.0                 NaN
# 115              NaN              3.0                 NaN
# 116              NaN              1.0                 NaN
# 117              NaN              NaN                 NaN
#
#      weaponKills.hkp2000  weaponKills.xm1014 weaponKills.mp9 weaponKills.mag7  \
# 0                    NaN                 NaN             NaN              NaN
# 1                    NaN                 NaN             NaN              NaN
# 2                    NaN                 NaN             NaN              NaN
# 3                    NaN                 NaN             NaN              NaN
# 4                    NaN                 NaN             NaN              NaN
# ..                   ...                 ...             ...              ...
# 113                  NaN                 NaN             NaN              NaN
# 114                  NaN                 NaN             NaN              NaN
# 115                  NaN                 NaN             NaN              NaN
# 116                  NaN                 NaN             NaN              NaN
# 117                  NaN                 NaN             NaN              NaN
#
#      weaponKills.cz75a  weaponKills.famas  weaponKills.tec9
# 0                  NaN                NaN               NaN
# 1                  NaN                NaN               NaN
# 2                  NaN                NaN               NaN
# 3                  NaN                NaN               NaN
# 4                  NaN                NaN               NaN
# ..                 ...                ...               ...
# 113                NaN                NaN               NaN
# 114                NaN                NaN               NaN
# 115                NaN                NaN               NaN
# 116                NaN                NaN               NaN
# 117                NaN                NaN               NaN
#
# [118 rows x 48 columns]

# %%
target_state_teams_players=pd.DataFrame()
for index,row in y.iterrows():
    target_state_teams_players=pd.concat([target_state_teams_players,pd.json_normalize(row['players'])])
target_state_teams_players.reset_index(drop=True,inplace=True)
z=target_state_teams_players
#z.to_excel('target_state_teams_players.xlsx',index=False)
z
# Out:
#                     id                      statePath segmentType     name  \
# 0    76561198350362302  [{'id': '76561198350362302'}]       round   r3salt
# 1    76561198059614402  [{'id': '76561198059614402'}]       round    zorte
# 2    76561198365697700  [{'id': '76561198365697700'}]       round  shalfey
# 3    76561198026088156  [{'id': '76561198026088156'}]       round    Jerry
# 4    76561198031908632  [{'id': '76561198031908632'}]       round     Krad
# ..                 ...                            ...         ...      ...
# 585  76561198076696741  [{'id': '76561198076696741'}]       round    Kylar
# 586  76561198260883606  [{'id': '76561198260883606'}]       round    Goofy
# 587  76561198050922008  [{'id': '76561198050922008'}]       round    hades
# 588  76561198081687729  [{'id': '76561198081687729'}]       round      KEi
# 589  76561197985246786  [{'id': '76561197985246786'}]       round    mynio
#
#      kills  killAssistsReceived  killAssistsGiven  \
# 0        0                    0                 0
# 1        1                    0                 0
# 2        0                    0                 0
# 3        2                    0                 1
# 4        2                    1                 0
# ..     ...                  ...               ...
# 585      0                    0                 0
# 586      1                    1                 0
# 587      0                    0                 0
# 588      0                    0                 1
# 589      1                    0                 0
#
#                          killAssistsReceivedFromPlayer  teamkills  \
# 0                                                   []          0
# 1                                                   []          0
# 2                                                   []          0
# 3                                                   []          0
# 4    [{'id': 'killAssistsReceivedFromPlayer-7656119...          0
# ..                                                 ...        ...
# 585                                                 []          0
# 586  [{'id': 'killAssistsReceivedFromPlayer-7656119...          0
# 587                                                 []          0
# 588                                                 []          0
# 589                                                 []          0
#
#      teamkillAssistsReceived  ...  weaponKills.hegrenade weaponKills.awp  \
# 0                          0  ...                    NaN             NaN
# 1                          0  ...                    NaN             NaN
# 2                          0  ...                    NaN             NaN
# 3                          0  ...                    NaN             NaN
# 4                          0  ...                    NaN             NaN
# ..                       ...  ...                    ...             ...
# 585                        0  ...                    NaN             NaN
# 586                        0  ...                    NaN             NaN
# 587                        0  ...                    NaN             NaN
# 588                        0  ...                    NaN             NaN
# 589                        0  ...                    NaN             NaN
#
#      weaponKills.molotov  weaponKills.hkp2000 weaponKills.xm1014  \
# 0                    NaN                  NaN                NaN
# 1                    NaN                  NaN                NaN
# 2                    NaN                  NaN                NaN
# 3                    NaN                  NaN                NaN
# 4                    NaN                  NaN                NaN
# ..                   ...                  ...                ...
# 585                  NaN                  NaN                NaN
# 586                  NaN                  NaN                NaN
# 587                  NaN                  NaN                NaN
# 588                  NaN                  NaN                NaN
# 589                  NaN                  NaN                NaN
#
#     weaponKills.mp9  weaponKills.mag7  weaponKills.cz75a  weaponKills.famas  \
# 0               NaN               NaN                NaN                NaN
# 1               NaN               NaN                NaN                NaN
# 2               NaN               NaN                NaN                NaN
# 3               NaN               NaN                NaN                NaN
# 4               NaN               NaN                NaN                NaN
# ..              ...               ...                ...                ...
# 585             NaN               NaN                NaN                NaN
# 586             NaN               NaN                NaN                NaN
# 587             NaN               NaN                NaN                NaN
# 588             NaN               NaN                NaN                NaN
# 589             NaN               NaN                NaN                NaN
#
#      weaponKills.tec9
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 585               NaN
# 586               NaN
# 587               NaN
# 588               NaN
# 589               NaN
#
# [590 rows x 50 columns]

# %%
x.shape
# Out:
# (59, 567)

# %%
y.shape
# Out:
# (118, 48)

# %%
z.shape
# Out:
# (590, 50)

# %%
r3salt = z.loc[(z['name']=='r3salt')]
r3salt.reset_index(drop=True,inplace=True)
r3salt['round_id']=range(1,len(r3salt)+1)
cols=r3salt.columns.to_list()
cols=['round_id']+cols[:-1]
r3salt=r3salt[cols]
#r3salt
#r3salt_and_kills.to_excel("r3salt.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\3288448307.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r3salt['round_id']=range(1,len(r3salt)+1)

# %%
zorte=z.loc[(z['name']=='zorte')]
zorte.reset_index(drop=True,inplace=True)
zorte['round_id']=range(1,len(zorte)+1)
cols=zorte.columns.to_list()
cols=['round_id']+cols[:-1]
zorte=zorte[cols]
#zorte
#cols
#zorte_and_kills.to_excel("zorte.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\3144632004.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zorte['round_id']=range(1,len(zorte)+1)

# %%
shalfey=z.loc[(z['name']=='shalfey')]
shalfey.reset_index(drop=True,inplace=True)
shalfey['round_id']=range(1,len(shalfey)+1)
cols=shalfey.columns.to_list()
cols=['round_id']+cols[:-1]
shalfey=shalfey[cols]
#shalfey
#shalfey_and_kills.to_excel("shalfey.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\2322505299.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shalfey['round_id']=range(1,len(shalfey)+1)

# %%
Jerry=z.loc[(z['name']=='Jerry')]
Jerry.reset_index(drop=True,inplace=True)
Jerry['round_id']=range(1,len(Jerry)+1)
cols=Jerry.columns.to_list()
cols=['round_id']+cols[:-1]
Jerry=Jerry[cols]
#Jerry
#jerry_and_kills.to_excel("jerry.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\1442742329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jerry['round_id']=range(1,len(Jerry)+1)

# %%
Krad=z.loc[(z['name']=='Krad')]
Krad.reset_index(drop=True,inplace=True)
Krad['round_id']=range(1,len(Krad)+1)
cols=Krad.columns.to_list()
cols=['round_id']+cols[:-1]
Krad=Krad[cols]
#Krad
#krad_and_kills.to_excel("krad.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\2106102621.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Krad['round_id']=range(1,len(Krad)+1)

# %%
Kylar=z.loc[(z['name']=='Kylar')]
Kylar.reset_index(drop=True,inplace=True)
Kylar['round_id']=range(1,len(Kylar)+1)
cols=Kylar.columns.to_list()
cols=['round_id']+cols[:-1]
Kylar=Kylar[cols]
#Kylar

#kylar_and_kills.to_excel("kylar.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\116288670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kylar['round_id']=range(1,len(Kylar)+1)

# %%
Goofy=z.loc[(z['name']=='Goofy')]
Goofy.reset_index(drop=True,inplace=True)
Goofy['round_id']=range(1,len(Goofy)+1)
cols=Goofy.columns.to_list()
cols=['round_id']+cols[:-1]
Goofy=Goofy[cols]
#Goofy
#goofy_and_kills.to_excel("goofy.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\613804516.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Goofy['round_id']=range(1,len(Goofy)+1)

# %%
hades=z.loc[(z['name']=='hades')]
hades.reset_index(drop=True,inplace=True)
hades['round_id']=range(1,len(hades)+1)
cols=hades.columns.to_list()
cols=['round_id']+cols[:-1]
hades=hades[cols]
#hades
#hades_and_kills.to_excel("hades.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\1319535223.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hades['round_id']=range(1,len(hades)+1)

# %%
KEi=z.loc[(z['name']=='KEi')]
KEi.reset_index(drop=True,inplace=True)
KEi['round_id']=range(1,len(KEi)+1)
cols=KEi.columns.to_list()
cols=['round_id']+cols[:-1]
KEi=KEi[cols]
#KEi
#kei_and_kills.to_excel("kei.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\2035568050.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KEi['round_id']=range(1,len(KEi)+1)

# %%
mynio=z.loc[(z['name']=='mynio')]
mynio.reset_index(drop=True,inplace=True)
mynio['round_id']=range(1,len(mynio)+1)
cols=mynio.columns.to_list()
cols=['round_id']+cols[:-1]
mynio=mynio[cols]
#mynio
#mynio_and_kills.to_excel("mynio.xlsx",index=False)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_14144\1687056811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mynio['round_id']=range(1,len(mynio)+1)

# %%
y
#y.info()
#y.describe()
y.isnull().sum()
y.groupby('name')['kills'].sum()
#y.groupby('side')['damageDealt'].sum()
# Out:
# name
# 9INE     188
# forZe    221
# Name: kills, dtype: int64

# %%
y[y['name']=='forZe'].groupby('side')['kills'].sum()
# Out:
# side
# counter-terrorists    125
# terrorists             96
# Name: kills, dtype: int64

# %%
y[y['name']=='9INE'].groupby('side')['kills'].sum()
# Out:
# side
# counter-terrorists     86
# terrorists            102
# Name: kills, dtype: int64

# %%
y['K/D']=y['kills']/y['deaths']

team_KD=y[y['name']=='forZe'].groupby('name')['K/D'].mean()
#team_KD.plot(kind='bar')
#plt.xlabel("won")
#plt.ylabel("kills")
#plt.xticks(rotation=45)
#plt.show()
#y['K/D']
team_KD
# Out:
# name
# forZe   NaN
# Name: K/D, dtype: float64

# %%
datum=[pd.DataFrame(r3salt),
       pd.DataFrame(zorte),
       pd.DataFrame(shalfey),
       pd.DataFrame(Jerry),
       pd.DataFrame(Krad),
       pd.DataFrame(Kylar),
       pd.DataFrame(Goofy),
       pd.DataFrame(hades),
       pd.DataFrame(KEi),
       pd.DataFrame(mynio)]

#def round_details(df,p1,p2):
    #req_columns=['round_id','name','kills','deaths','damageDealt','damageTaken','headshots']
    #data_dict={p1:[],p2:[]}
   

    #for index,row in df.iterrows():
        #player_name=row['name']

        #if player_name == p1:
            #round_data = {col: row[col] for col in req_columns}
            #data_dict[p1].append(round_data)
        
        #elif player_name == p2:
            #round_data = {col: row[col] for col in req_columns}
            #data_dict[p2].append(round_data)
        
        # if round_id != current_round:
        #     # if current_player:
        #     #     data_list.append({f'round_id': current_round,**round_data_1[current_player]})
        #     #     data_list.append({f'round_id': current_round,**round_data_2[current_player]})
        #     current_round=round_id
        #     print("called")

        #player_name=row['name']
        #if player_name==p1:
         #       current_player=player_name
         #       round_data_1[current_player].update({col:row[col] for col in req_columns})
        
        #if player_name==p2:
         #    current_player=player_name
          #   round_data_2[current_player].update({col:row[col] for col in req_columns})
                    
   # if current_player:
    #    data_list.append({f'round_id': round_id,**round_data_1[current_player]})
     #   data_list.append({f'round_id': round_id,**round_data_2[current_player]})
    #return data_dict
    

#p1='r3salt'
#p2='Kaylar'

#round_data_list=[]


#for df_name,df in zip(['r3salt','zorte','shalfey','Jerry','Krad','Kylar','Goofy','hades','KEi','mynio'],datum):
#    round_details_gen=round_details(df,p1,p2)

#      if round_details_gen[p1]:
#           data_dict={"pid":p1,"data":round_details_gen[p1]}
#           round_data_list.append(data_dict)

#       if round_details_gen[p2]:
#           data_dict={"pid":p2,"data":round_details_gen[p2]}
#           round_data_list.append(data_dict)
        

#print("Raw round_data_dict:")
#print(round_data_dict)

# Filter out entries with empty lists for both p1 and p2 from the beginning and end
#filtered_round_data_dict = {key: value for key, value in round_data_dict.items() if any(value[p1]) or any(value[p2])}

#print("\nFiltered round_data_dict:")
#print(filtered_round_data_dict)



#filtered_round_data_dict=[{key:value for key,value in round_data_dict.items() if any (value)}]
    #for round_data in round_details_gen:
#print(filtered_round_data_dict)
#filtered_round_data_dict = {key: value for key, value in round_data_dict.items() if any(value[p1]) or any(value[p2])}
#print(round_data_list)
# Out:
# [{'pid': 'r3salt', 'data': [{'round_id': 1, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 2, 'name': 'r3salt', 'kills': 1, 'deaths': 0, 'damageDealt': 166, 'damageTaken': 31, 'headshots': 1}, {'round_id': 3, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 73, 'damageTaken': 100, 'headshots': 0}, {'round_id': 4, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 5, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 156, 'damageTaken': 100, 'headshots': 0}, {'round_id': 6, 'name': 'r3salt', 'kills': 4, 'deaths': 0, 'damageDealt': 375, 'damageTaken': 54, 'headshots': 3}, {'round_id': 7, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 27, 'damageTaken': 100, 'headshots': 0}, {'round_id': 8, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 100, 'damageTaken': 100, 'headshots': 1}, {'round_id': 9, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 25, 'damageTaken': 100, 'headshots': 0}, {'round_id': 10, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 11, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 12, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 12, 'damageTaken': 92, 'headshots': 0}, {'round_id': 13, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 27, 'damageTaken': 100, 'headshots': 1}, {'round_id': 14, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 15, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 100, 'damageTaken': 100, 'headshots': 1}, {'round_id': 16, 'name': 'r3salt', 'kills': 0, 'deaths': 0, 'damageDealt': 0, 'damageTaken': 0, 'headshots': 0}, {'round_id': 17, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 122, 'damageTaken': 100, 'headshots': 0}, {'round_id': 18, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 19, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 20, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 4, 'damageTaken': 100, 'headshots': 0}, {'round_id': 21, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 22, 'name': 'r3salt', 'kills': 3, 'deaths': 0, 'damageDealt': 297, 'damageTaken': 82, 'headshots': 3}, {'round_id': 23, 'name': 'r3salt', 'kills': 2, 'deaths': 1, 'damageDealt': 200, 'damageTaken': 100, 'headshots': 0}, {'round_id': 24, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 25, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 75, 'damageTaken': 100, 'headshots': 1}, {'round_id': 26, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 24, 'damageTaken': 100, 'headshots': 0}, {'round_id': 27, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 0, 'damageTaken': 100, 'headshots': 0}, {'round_id': 28, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 23, 'damageTaken': 100, 'headshots': 0}, {'round_id': 29, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 22, 'damageTaken': 100, 'headshots': 0}, {'round_id': 30, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 158, 'damageTaken': 100, 'headshots': 0}, {'round_id': 31, 'name': 'r3salt', 'kills': 0, 'deaths': 0, 'damageDealt': 0, 'damageTaken': 0, 'headshots': 0}, {'round_id': 32, 'name': 'r3salt', 'kills': 1, 'deaths': 0, 'damageDealt': 44, 'damageTaken': 0, 'headshots': 0}, {'round_id': 33, 'name': 'r3salt', 'kills': 0, 'deaths': 1, 'damageDealt': 32, 'damageTaken': 100, 'headshots': 0}, {'round_id': 34, 'name': 'r3salt', 'kills': 1, 'deaths': 1, 'damageDealt': 100, 'damageTaken': 83, 'headshots': 0}, {'round_id': 35, 'name': 'r3salt', 'kills': 0, 'dea ...

# %%
#[{"pid":"Jerry","data":[]},{"pid":"mynio","data":[]}]

# %%
#def player_names(data):
#    name=set()

#    for df in data:
#        if 'name' in df.columns:
#            name.update(df['name'].unique())
#    return list(name)

#players=player_names(datum)
#print(players)
# Out:
# ['r3salt', 'zorte', 'Jerry', 'Krad', 'Goofy', 'hades', 'KEi', 'mynio', 'Kylar', 'shalfey']
